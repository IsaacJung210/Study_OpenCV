# %% [markdown]
# # 2. 동영상 출력
# https://www.pexels.com/ko-kr/ 에서 동영상을 다운 받기

# %% [markdown]
# ## 동영상 파일 출력

# %%
import cv2
cap = cv2.VideoCapture('video.mp4')

while cap.isOpened(): # 동영상 파일이 올바로 열렸는지?
    ret,  frame = cap.read() # ret : 성공 여부, frame : 받아온 이미지 (프레임)
    if not ret:
        print('더 이상 가져올 프레임이 없어요.')
        break
        
    cv2.imshow('video', frame)
    
    if cv2.waitKey(1) == ord('q'):
        print('사용자 입력에 의해 종료합니다.')
        break
        
cap.release() # 자원 해제
cv2.destroyAllWindows() # 모든 창 닫기
# Out:
# 더 이상 가져올 프레임이 없어요.

# %% [markdown]
# ***

# %% [markdown]
# ## 카메라 출력

# %%
import cv2
cap = cv2.VideoCapture(1) # 1번째 카메라 장치 (Device ID) (숫자는 0번부터 시작한다.)

if not cap.isOpened(): # 카메라가 잘 열리지 않은 경우
    exit() # 프로그램 종료
    
while True:
    ret, frame = cap.read()
    if not ret:
        break
        
    cv2.imshow('camera', frame)
    if cv2.waitKey(1)  == ord('q'): # 사용자가 q를 입력하면
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 카메라 좌우대칭 출력

# %%
import cv2
cap = cv2.VideoCapture(1) # 1번째 카메라 장치 (Device ID) (숫자는 0번부터 시작한다.)

if not cap.isOpened(): # 카메라가 잘 열리지 않은 경우
    exit() # 프로그램 종료
    
while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    flip_horizontal = cv2.flip(frame, 1) # flipCode > 0 : 좌우 대칭 Horizontal
    cv2.imshow('camera', flip_horizontal)
    if cv2.waitKey(1)  == ord('q'): # 사용자가 q를 입력하면
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12428\2260363158.py in <module>
#       6
#       7 while True:
# ----> 8     ret, frame = cap.read()
#       9     if not ret:
#      10         break
#
# KeyboardInterrupt:
